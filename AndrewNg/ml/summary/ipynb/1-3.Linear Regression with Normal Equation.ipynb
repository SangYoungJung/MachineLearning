# %% [markdown]
# ## Linear Regression with Normal Equation
# ####  Contents
# - [Formula](#Formula)
# - [Example](#Example)
# - [Comparison with gradient descent](#Comparison-with-gradient-descent)
# - [Noninvertibility](#Noninvertibility)
# ---

# %% [markdown]
# ### Formula
# Solve for $ \theta_0, \theta_1, \dots, \theta_n $, $ \theta \in R^{n+1}$
# $x^{(i)}=\left[\begin{array}{ccc}
# x_{0}^{(i)} \\ x_{1}^{(i)} \\ \dots \\ x_{0}^{(i)} \\
# \end{array}\right]
# \theta^{(i)}=\left[\begin{array}{ccc}
# \theta_{0}^{(i)} \\ \theta_{1}^{(i)} \\ \dots \\ \theta_{0}^{(i)} \\
# \end{array}\right]$
#
# $ x \in R^{n+1} $
# $ \theta \in R^{n+1} $
#
#
# $X=\left[\begin{array}{ccc}
# 1 & \dots & x^{(1)^T} & \dots \\
# 1 & \dots & x^{(2)^T} & \dots \\
# 1 & \dots & \dots & \dots \\
# 1 & \dots & x^{(m)^T} & \dots \\
# \end{array}\right]
# y=\left[\begin{array}{ccc}
# y^{(1)} \\ y^{(2)} \\ \dots \\ y^{(m)} \\
# \end{array}\right]
# $
#
#
# $$ \theta = (X^{T}X)^{-1}X^{T}y $$
#
# $X \cdot \theta = y$
# $X^T X \theta = X^T y$
# $(X^T X)^{-1}(X^T X) \theta = (X^T X)^{-1}X^T y$
# $\theta = (X^T X)^{-1}X^T y$

# %% [markdown]
# ### Example
# $m = 4, n = 4, x_0=1$
#
# $X=\left[\begin{array}{ccc}
# 1 & 2104 & 5 & 1 & 45 \\
# 1 & 1416 & 3 & 2 & 40 \\
# 1 & 1534 & 3 & 2 & 30 \\
# 1 & 852  & 1 & 1 & 36 \\
# \end{array}\right]$  $m * {(n+1)}$
#
# $Y=\left[\begin{array}{ccc}
# 460 \\ 232 \\ 315 \\ 178 \\
# \end{array}\right]$  m-dimentional vector

# %% [markdown]
# ### Comparison with gradient descent
# Gradient Descent | Normal Equation
# ---|---
# Need to choose alpha | No need to choose alpha
# Needs many iterations | No need to iterate
# $O(kn^2)$   | $O (n^3)$, need to calculate inverse of $(X^{T}X)$
# Works well when n is large | Works well when n is large

# %% [markdown]
# ### Noninvertibility
# If $ (X^{T}X) $ is noninvertible((singular/degenerate), the common causes might be having :
# * **Redundant** features, where two features are very closely related (i.e. they are linearly dependent)
# * Too many features (e.g. m ≤ n). In this case, delete some features or use **"regularization"**
