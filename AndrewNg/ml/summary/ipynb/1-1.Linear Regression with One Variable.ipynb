# %% [markdown]
# ## Linear Regression with One Variable
# ####  Contents
# - [Supervised Learning](#Supervised-Learning)
# - [Regression Problem](#Regression-Problem)
# - [Notation](#Notation)
# - [Model Representation](#Model-Representation)
# - [Cost Function](#Cost-Function)
# - [Gradient descent I](#Gradient-descent-I)
# - [Gradient descent II](#Gradient-descent-II)
# - [Batch Gradient descent](#Batch-Gradient-descent)
# ---

# %% [markdown]
# ### Supervised Learning
# Given the **"right answer"** for each example in the data.

# %% [markdown]
# ### Regression Problem
# Predict **real-valued** output
# Linear Regression with One Variable(or **Univariate Linear Regression**)

# %% [markdown]
# ### Notation
# * m: Number of traning examples
# * X's : "input" variable / features
# * Y's : "output" variable / "target" variable

# %% [markdown]
# ### Model Representation
# Hypothesis : $$ h_{\theta}(x) = {\theta_{0}}+{\theta_{1}}x_{1} $$
# Parameters : $$ {\theta_{0}}, {\theta_{1}}$$
# Cost Function : $$ J({\theta_{0}}, {\theta_{1}}) = \frac{1}{2m}\sum_{i = 1}^{n} (h_{\theta}(x^{(i)})-y^{(i)})^2$$
# Goal :
# $$ \begin{array}{ccc}
# minimize \\ {\theta_{0}}, {\theta_{1}}
# \end{array} J({\theta_{0}}, {\theta_{1}})$$
# $h_{\theta}(x)$ : for fixed $\theta_{0}, \theta_{1}$ this is a function of x
# $J({\theta_{0}}, {\theta_{1}})$ : function of the parameters $\theta_{0}, \theta_{1}$

# %% [markdown]
# ### Cost Function
# This function is otherwise called the "Squared error function", or "Mean squared error".
# $\frac{1}{2}$ as a convenience for the computation of the gradient descent.

# %% [markdown]
# ### Gradient descent I
# Outline
# * Start with some ${\theta_{0}}, {\theta_{1}}$
# * Keep changing ${\theta_{0}}, {\theta_{1}}$ to reduce $J({\theta_{0}}, {\theta_{1}})$ until we hopefully end up at a minimum.
#
# Algorithm : repeat until convergence
#     $$\theta_{j} := \theta_{j} - \alpha \frac{\partial}{\partial \theta_{j}} J({\theta_{0}}, {\theta_{1}})$$
#
# Correct Simultaneous update
# $$temp0 := \theta_{0} - \alpha \frac{\partial}{\partial \theta_{0}} J({\theta_{0}}, {\theta_{1}})$$
# $$temp1 := \theta_{1} - \alpha \frac{\partial}{\partial \theta_{1}} J({\theta_{0}}, {\theta_{1}})$$
# $$\theta_{0} = temp0$$
# $$\theta_{1} = temp1$$
#
#
# Learning Rate : ${\alpha}$
# * If ${\alpha}$ is too small, gradient descent can be slow.
# * If ${\alpha}$ is too large, gradient descent can overshoot the minimum. It may fail to converge, or even diverge.
# * As we approach a local minimum, gradient descent will automacally take smaller steps.So,no need to decrease ${\alpha}$ over time.

# %% [markdown]
# ### Gradient descent II
# Algorithm : repeat until convergence
# $$\theta_{0} := \theta_{0} - \alpha \frac{1}{m} \sum_{i = 1}^{m} (h_{\theta}(x^{(i)})-y^{(i)})$$
# $$\theta_{1} := \theta_{1} - \alpha \frac{1}{m} \sum_{i = 1}^{m} (h_{\theta}(x^{(i)})-y^{(i)})x^{(i)}$$
#
#
# $\frac{\partial}{\partial \theta_{0}} J({\theta_{0}}, {\theta_{1}}) = \frac{1}{m} \sum_{i = 1}^{n} (h_{\theta}(x^{(i)})-y^{(i)})$
# $\frac{\partial}{\partial \theta_{1}} J({\theta_{0}}, {\theta_{1}}) = \frac{1}{m} \sum_{i = 1}^{n} (h_{\theta}(x^{(i)})-y^{(i)})x^{(i)}$

# %% [markdown]
# ### Batch Gradient descent
# Batch : Each step of gradient descent uses all the training examples
